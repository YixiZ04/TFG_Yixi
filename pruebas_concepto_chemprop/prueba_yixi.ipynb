# %% [markdown]
# # Training with chemprop

# %%
import os
import pandas as pd
from lightning import pytorch as pl
from lightning.pytorch.callbacks import ModelCheckpoint
from chemprop import data, featurizers, models, nn

from chemprop.training import output_transform

# %%
path = os.getcwd ()
path
# Out:
# 'C:\\Users\\leonz\\PyCharmMiscProject\\chemprop'

# %%
filename = "regression.csv"
path_2_file = path + "\\" + filename
path_2_file
# Out:
# 'C:\\Users\\leonz\\PyCharmMiscProject\\chemprop\\regression.csv'

# %%
## Load the csv file
datos = pd.read_csv (path_2_file)
datos
# Out:
#                                                 smiles  logSolubility
# 0    OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...         -0.770
# 1                               Cc1occc1C(=O)Nc2ccccc2         -3.300
# 2                                 CC(C)=CCCC(C)=CC(=O)         -2.060
# 3                   c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43         -7.870
# 4                                              c1ccsc1         -1.330
# ..                                                 ...            ...
# 495                           Nc1cc(nc(N)n1=O)N2CCCCC2         -1.989
# 496                              Nc2cccc3nc1ccccc1cc23         -4.220
# 497                   c1ccc2cc3c4cccc5cccc(c3cc2c1)c45         -8.490
# 498          OC(c1ccc(Cl)cc1)(c2ccc(Cl)cc2)C(Cl)(Cl)Cl         -5.666
# 499                                 C1Cc2cccc3cccc1c23         -4.630
#
# [500 rows x 2 columns]

# %% [markdown]
# # Get smiles and targets

# %%
## Column informations
smiles_column = 'smiles'
target_columns = ['logSolubility']

# %%
# Get smiles and targets
smles = datos.loc [:, smiles_column].values
ys = datos.loc [:, target_columns].values

# %%
smles
# Out:
# array(['OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)C(O)C3O',
#        'Cc1occc1C(=O)Nc2ccccc2', 'CC(C)=CCCC(C)=CC(=O)',
#        'c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43', 'c1ccsc1', 'c2ccc1scnc1c2',
#        'Clc1cc(Cl)c(c(Cl)c1)c2c(Cl)cccc2Cl',
#        'CC12CCC3C(CCc4cc(O)ccc34)C2CCC1O',
#        'ClC4=C(Cl)C5(Cl)C3C1CC(C2OC12)C3C4(Cl)C5(Cl)Cl',
#        'COc5cc4OCC3Oc2c1CC(Oc1ccc2C(=O)C3c4cc5OC)C(C)=C', 'O=C1CCCN1',
#        'Clc1ccc2ccccc2c1', 'CCCC=C', 'CCC1(C(=O)NCNC1=O)c2ccccc2',
#        'CCCCCCCCCCCCCC', 'CC(C)Cl', 'CCC(C)CO', 'N#Cc1ccccc1',
#        'CCOP(=S)(OCC)Oc1cc(C)nc(n1)C(C)C', 'CCCCCCCCCC(C)O',
#        'Clc1ccc(c(Cl)c1)c2c(Cl)ccc(Cl)c2Cl',
#        'O=c2[nH]c1CCCc1c(=O)n2C3CCCCC3', 'CCOP(=S)(OCC)SCSCC',
#        'CCOc1ccc(NC(=O)C)cc1',
#        'CCN(CC)c1c(cc(c(N)c1N(=O)=O)C(F)(F)F)N(=O)=O', 'CCCCCCCO',
#        'Cn1c(=O)n(C)c2nc[nH]c2c1=O', 'CCCCC1(CC)C(=O)NC(=O)NC1=O',
#        'ClC(Cl)=C(c1ccc(Cl)cc1)c2ccc(Cl)cc2', 'CCCCCCCC(=O)OC',
#        'CCc1ccc(CC)cc1', 'CCOP(=S)(OCC)SCSC(C)(C)C',
#        'COC(=O)Nc1cccc(OC(=O)Nc2cccc(C)c2)c1', 'ClC(=C)Cl',
#        'Cc1cccc2c1Cc3ccccc32', 'CCCCC=O', 'N(c1ccccc1)c2ccccc2',
#        'CN(C)C(=O)SCCCCOc1ccccc1', 'CCCOP(=S)(OCCC)SCC(=O)N1CCCCC1C',
#        'CCCCCCCI', 'c1c(Cl)cccc1c2ccccc2', 'OCCCC=C',
#        'O=C2NC(=O)C1(CCC1)C(=O)N2', 'CC(C)C1CCC(C)CC1O', 'CC(C)OC=O',
#        'CCCCCC(C)O', 'CC(=O)Nc1ccc(Br)cc1', 'c1ccccc1n2ncc(N)c(Br)c2(=O)',
#        'COC(=O)C1=C(C)NC(=C(C1c2ccccc2N(=O)=O)C(=O)OC)C',
#        'c2c(C)cc1nc(C)ccc1c2', 'CCCCCCC#C',
#        'CCC1(C(=O)NC(=O)NC1=O)C2=CCCCC2', 'c1ccc2c(c1)ccc3c4ccccc4ccc23',
#        'CCC(C)n1c(=O)[nH]c(C)c(Br)c1=O',
#        'Clc1cccc(c1Cl)c2c(Cl)c(Cl)cc(Cl)c2Cl', 'Cc1ccccc1O',
#        'CC(C)CCC(C)(C)C', 'Cc1ccc(C)c2ccccc12',
#        'Cc1cc2c3ccccc3ccc2c4ccccc14', 'CCCC(=O)C',
#        'Clc1cc(Cl)c(Cl)c(c1Cl)c2c(Cl)c(Cl)cc(Cl)c2Cl', 'CCCOC(=O)CC',
#        'CC34CC(O)C1(F)C(CCC2=CC(=O)C=CC12C)C3CC(O)C4(O)C(=O)CO',
#        'Nc1ccc(O)cc1', 'O=C(Cn1ccnc1N(=O)=O)NCc2ccccc2',
#        'OC4=C(C1CCC(CC1)c2ccc(Cl)cc2)C(=O)c3ccccc3C4=O',
#        'CCNc1nc(Cl)nc(n1)N(CC)CC', 'NC(=O)c1cnccn1',
#        'CCC(Br)(CC)C(=O)NC(N)=O', 'Clc1ccccc1c2ccccc2Cl',
#        'O=C2CN(N=Cc1ccc(o1)N(=O)=O)C(=O)N2',
#        'Clc2ccc(Oc1ccc(cc1)N(=O)=O)c(Cl)c2', 'CC1(C)C2CCC1(C)C(=O)C2',
#        'O=C1NC(=O)NC(=O)C1(CC=C)c1ccccc1', 'CCCCC(=O)OCC',
#        'CC(C)CCOC(=O)C',
#        'O=C1N(COC(=O)CCCCC)C(=O)C(N1)(c2ccccc2)c3ccccc3',
#        'Clc1cccc(c1)c2cc(Cl)ccc2Cl', 'CCCBr',
#        'CCCC1COC(Cn2cncn2)(O1)c3ccc(Cl)cc3Cl',
#        'COP(=S)(OC)SCC(=O)N(C)C=O', 'Cc1ncnc2nccnc12', 'NC(=S)N',
#        'Cc1ccc(C)cc1', 'CCc1ccccc1CC', 'ClC(Cl)(Cl)C(Cl)(Cl)Cl',
#        'CC(C)C(C(=O)OC(C#N)c1cccc(Oc2ccccc2)c1)c3ccc(OC(F)F)cc3',
#        'CCCN(=O)=O', 'CC(C)C1CCC(C)CC1=O',
#        'CCN2c1cc(Cl)ccc1NC(=O)c3cccnc23', 'O=N(=O)c1c(Cl)c(Cl)ccc1',
#        'CCCC(C)C1(CC=C)C(=O)NC(=S)NC1=O', 'c1ccc2c(c1)c3cccc4cccc2c34',
#        'CCCOC(C)C', 'Cc1cc(C)c2ccccc2c1',
#        'CCC(=C(CC)c1ccc(O)cc1)c2ccc(O)cc2',
#        'c1(C#N)c(Cl)c(C#N)c(Cl)c(Cl)c(Cl)1',
#        'Clc1ccc(Cl)c(c1)c2ccc(Cl)c(Cl)c2', 'C1OC1c2ccccc2',
#        'CC(C)c1ccccc1', 'CC12CCC3C(CCC4=CC(=O)CCC34C)C2CCC1C(=O)CO',
#        'c2(Cl)c(Cl)c(Cl)c1nccnc1c2(Cl)', 'C1OC(O)C(O)C(O)C1O', 'ClCCl',
#        'CCc1cccc2ccccc12', 'COC=O', 'Oc1ccccc1N(=O)=O',
#        'Cc1c[nH]c(=O)[nH]c1=O', 'CC(C)C',
#        'OCC1OC(C(O)C1O)n2cnc3c(O)ncnc23', 'Oc1c(I)cc(C#N)cc1I',
#        'Oc1ccc(Cl)cc1C(=O)Nc2ccc(cc2Cl)N(=O)=O', 'CCCCC', 'c1ccccc1O',
#        'Nc3ccc2cc1ccccc1cc2c3', 'Cn1cnc2n(C)c(=O)[nH]c(=O)c12',
#        'c1ccc2cnccc2c1', 'COP(=S)(OC)SCC(=O)N(C(C)C)c1ccc(Cl)cc1',
#        'CCCCCCc1ccccc1', 'Clc1ccccc1c2ccccc2', 'CCCC(=C)C',
#        'CC(C)C(C)C(C)C', 'Clc1cc(Cl)c(Cl)c(Cl)c1Cl', 'Oc1cccc(c1)N(=O)=O',
#        'CCCCCCCCC=C', 'CC(=O)OCC(COC(=O)C)OC(=O)C',
#        'CCCCc1c(C)nc(nc1O)N(C)C',
#        'CC1(C)C(C=C(Cl)Cl)C1C(=O)OC(C#N)c2ccc(F)c(Oc3ccccc3)c2',
#        'c1ccncc1', 'CCCCCCCBr', 'Cc1ccncc1C',
#        'CC34CC(O)C1(F)C(CCC2=CC(=O)CCC12C)C3CCC4(O)C(=O)CO',
#        'CCSCc1ccccc1OC(=O)NC', 'CCOC(=O)CC(=O)OCC', 'CC1=CCC(CC1)C(C)=C',
#        'C1Cc2ccccc2C1', 'CC(C)(C)c1ccc(O)cc1', 'O=C2NC(=O)C1(CC1)C(=O)N2',
#        'Clc1cccc(I)c1', 'Brc1cccc2ccccc12', 'CC/C=C/C', 'Cc1cccc(C)n1',
#        'ClC=C(Cl)Cl', 'Nc1cccc2ccccc12', 'Cc1cccc(C)c1',
#        'Oc2ncc1nccnc1n2', 'CO', 'CCC1(CCC(C)C)C(=O)NC(=O)NC1=O',
#        'CCC(=O)C', 'Fc1c[nH]c(=O)[nH]c1=O',
#        'Nc1ncnc2n(ccc12)C3OC(CO)C(O)C3O', 'Oc1cccc(O)c1', 'CCCCCCO',
#        'CCCCCCl', 'C=CC=C', 'CCCOC(=O)C', 'Oc2ccc1CCCCc1c2', 'NC(=O)CCl',
#        'COP(=S)(OC)Oc1cc(Cl)c(I)cc1Cl', 'Cc1ccc(Cl)cc1',
#        'CSc1nnc(c(=O)n1N)C(C)(C)C',
#        'Cc1ccc(OP(=O)(Oc2cccc(C)c2)Oc3ccccc3C)cc1', 'CCCCCC=O',
#        'CCCCOC(=O)c1ccc(N)cc1', 'O2c1cc(C)ccc1N(C)C(=O)c3cc(N)cnc23',
#        'CC(C)=CCC/C(C)=C\\CO', 'Clc1ccc(cc1)c2ccccc2Cl',
#        'O=C1N(COC(=O)CCCCCCC)C(=O)C(N1)(c2ccccc2)c3ccccc3', 'CCN(=O)=O',
#        'CCN(CC(C)=C)c1c(cc(cc1N(=O)=O)C(F)(F)F)N(=O)=O',
#        'Clc1ccc(Cl)c(Cl)c1Cl', 'CCCC(C)(COC(N)=O)COC(N)=O',
#        'CC(=O)C3CCC4C2CC=C1CC(O)CCC1(C)C2CCC34C', 'CI',
#        'CC1CC(C)C(=O)C(C1)C(O)CC2CC(=O)NC(=O)C2',
#        'O=C1N(COC(=O)CCCCCC)C(=O)C(N1)(c2ccccc2)c3ccccc3',
#        'CC1=CC(=O)CC(C)(C)C1', 'O=C1NC(=O)NC(=O)C1(CC)C(C)CC',
#        'CCCCC(=O)CCCC', 'CCC1(CCC(=O)NC1=O)c2ccccc2', 'CCC(C)CC',
#        'CCOc1ccc(cc1)C(C)(C)COCc3cccc(Oc2ccccc2)c3',
#        'Cc1ccccc1n3c(C)nc2ccccc2c3=O', 'ClCC#N',
#        'CCOP(=S)(CC)Oc1cc(Cl)c(Cl)cc1Cl',
#        'CC12CCC(=O)C=C1CCC3C2CCC4(C)C3CCC4(O)C#C', 'c1ccnnc1',
#        'Clc1cc(Cl)c(Cl)c(Cl)c1',
#        'C1C(O)CCC2(C)CC3CCC4(C)C5(C)CC6OCC(C)CC6OC5CC4C3C=C21',
#        'Nc1ccccc1O', 'CCCCCCCCC(=O)OCC',
#        'COCC(=O)N(C(C)C(=O)OC)c1c(C)cccc1C', 'CNC(=O)Oc1ccccc1OC(C)C',
#        'CCC(C)Cl', 'Oc1ccc2ccccc2c1',
#        'CC(C)Oc1cc(c(Cl)cc1Cl)n2nc(oc2=O)C(C)(C)C', 'CCCCC#C',
#        'CCCCCCCC#C', 'Cc1ccccc1Cl', 'CC(C)OC(C)C',
#        'Nc1ccc(cc1)S(=O)(=O)c2ccc(N)cc2', 'CNN', 'CC#C',
#        'CCOP(=S)(OCC)ON=C(C#N)c1ccccc1', 'CCNP(=S)(OC)OC(=CC(=O)OC(C)C)C',
#        'C=CC=O', 'O=c1[nH]cnc2nc[nH]c12', 'Oc2ccc1ncccc1c2', 'Fc1ccccc1',
#        'CCCCl', 'CCOC(=O)C', 'CCCC(C)(C)C', 'Cc1cc(C)c(C)c(C)c1C',
#        'CC12CCC(CC1)C(C)(C)O2', 'CCCCOC(=O)CCCCCCCCC(=O)OCCCC',
#        'Clc1ccc(cc1)c2ccc(Cl)cc2', 'Cc1cccnc1C', 'CC(=C)C1CC=C(C)C(=O)C1',
#        'CCOP(=S)(OCC)SCSc1ccc(Cl)cc1',
#        'COc1cc(cc(OC)c1O)C6C2C(COC2=O)C(OC4OC3COC(C)OC3C(O)C4O)c7cc5OCOc5cc67',
#        'c1cc2cccc3c4cccc5cccc(c(c1)c23)c54', 'Cc1ccc(cc1N(=O)=O)N(=O)=O',
#        'c1c(Br)ccc2ccccc12', 'CNC(=O)Oc1cccc(N=CN(C)C)c1',
#        'COc2cnc1ncncc1n2', 'Cc3ccnc4N(C1CC1)c2ncccc2C(=O)Nc34',
#        'CCOP(=S)(OCC)Oc1nc(Cl)n(n1)C(C)C', 'CC(=C)C=C',
#        'CC(C)=CCCC(O)(C)C=C', 'COP(=S)(OC)Oc1ccc(SC)c(C)c1', 'OC1CCCCC1',
#        'O=C1NC(=O)NC(=O)C1(C)CC=C', 'CC34CCC1C(CCC2CC(O)CCC12C)C3CCC4=O',
#        'OCC(O)C(O)C(O)C(O)CO', 'Cc1ccc(cc1)c2ccccc2',
#        'CCNc1nc(Cl)nc(NC(C)C)n1', 'NC(=S)Nc1ccccc1', 'CCCC(=O)CCC',
#        'CC(=O)C(C)(C)C', 'Oc1ccc(Cl)cc1', 'O=C1CCCCC1', 'Cc1cccc(N)c1',
#        'ClC(Cl)(Cl)C#N', 'CNc2cnn(c1cccc(c1)C(F)(F)F)c(=O)c2Cl',
#        'CCCCCCCCC(=O)C', 'CCN(CC)c1nc(Cl)nc(NC(C)C)n1',
#        'CCOC(=O)c1ccc(N)cc1', 'Clc1ccc(Cl)c(Cl)c1',
#        'Cc3nnc4CN=C(c1ccccc1Cl)c2cc(Cl)ccc2n34', 'Oc1ccccc1O',
#        'CCN2c1ncccc1N(C)C(=O)c3cccnc23', 'CSC', 'Cc1ccccc1Br',
#        'CCOC(=O)N',
#        'CC(=O)OC3(CCC4C2C=C(C)C1=CC(=O)CCC1(C)C2CCC34C)C(C)=O',
#        'CC(C)C(O)C(C)C', 'c1ccc2ccccc2c1', 'CCNc1ccccc1',
#        'O=C1NC(=O)C(N1)(c2ccccc2)c3ccccc3',
#        'Cc1c2ccccc2c(C)c3ccc4ccccc4c13',
#        'CCOP(=S)(OCC)SC(CCl)N1C(=O)c2ccccc2C1=O',
#        'COc1ccc(cc1)C(c2ccc(OC)cc2)C(Cl)(Cl)Cl',
#        'Fc1cccc(F)c1C(=O)NC(=O)Nc2cc(Cl)c(F)c(Cl)c2F',
#        'O=C1N(COC(=O)CCCC)C(=O)C(N1)(c2ccccc2)c3ccccc3',
#        'CN(C)C(=O)Nc1ccc(Cl)cc1', 'OC(Cn1cncn1)(c2ccc(F)cc2)c3ccccc3F',
#        'CC(=O)OCC(=O)C3(O)C(CC4C2CCC1=CC(=O)C=CC1(C)C2(F)C(O)CC34C)OC(C)=O',
#        'CCCCBr', 'Brc1cc(Br)c(Br)cc1Br', 'CC(C)CC(=O)C',
#        'CCSC(=O)N(CC)C1CCCCC1', 'COc1ccc(Cl)cc1',
#        'CC1(C)C(C=C(Br)Br)C1C(=O)OC(C#N)c2cccc(Oc3ccccc3)c2',
#        'CCC(C)C1(CC=C)C(=O)NC(=O)NC1=O',
#        'COP(=S)(OC)Oc1ccc(N(=O)=O)c(C)c1', 'Ic1cccc2ccccc12',
#        'OCC(O)C(O)C(O)C(O)CO', 'CCS', 'ClCC(Cl)Cl',
#        'CN(C)C(=O)Oc1cc(C)nn1c2ccccc2', 'NC(=O)c1ccccc1O',
#        'Cc1ccccc1N(=O)=O', 'O=C1NC(=O)NC(=O)C1(C(C)C)C(C)C',
#        'CCc1ccccc1C', 'CCCCCCCCl', 'O=C1NC(=O)NC(=O)C1(CC)CC',
#        'C(Cc1ccccc1)c2ccccc2', 'ClC(Cl)C(Cl)Cl',
#        'CCN2c1cc(OC)cc(C)c1NC(=O)c3cccnc23', 'Cc1ccc2c(ccc3ccccc32)c1',
#        'CCCCOC(=O)c1ccccc1C(=O)OCCCC', 'COc1c(O)c(Cl)c(Cl)c(Cl)c1Cl',
#        'CCN(CC)C(=O)C(=CCOP(=O)(OC)OC)Cl',
#        'CC34CCC1C(=CCc2cc(O)ccc12)C3CCC4=O',
#        'CCOC(=O)c1ccccc1S(=O)(=O)NN(C=O)c2nc(Cl)cc(OC)n2',
#        'COc1ccc(cc1)N(=O)=O', 'CCCCCCCl',
#        'Clc1cc(c(Cl)c(Cl)c1Cl)c2cc(Cl)c(Cl)c(Cl)c2Cl',
#        'OCC1OC(CO)(OC2OC(COC3OC(CO)C(O)C(O)C3O)C(O)C(O)C2O)C(O)C1O',
#        'CCCCCCCCCCCCCCCCCCCCCCCCCC', 'CCN2c1ccccc1N(C)C(=O)c3cccnc23',
#        'CC(Cl)Cl', 'Nc1ccc(cc1)S(N)(=O)=O',
#        'CCCN(CCC)c1c(cc(cc1N(=O)=O)C(C)C)N(=O)=O',
#        'ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl',
#        'CCOP(=S)(NC(C)C)Oc1ccccc1C(=O)OC(C)C', 'Clc1cccc(Cl)c1Cl',
#        'ClC(Cl)(Cl)Cl', 'O=N(=O)c1cc(Cl)c(Cl)cc1', 'OC1CCCCCCC1',
#        'CC1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3CCC21C', 'CCOc1ccc(NC(N)=O)cc1',
#        'C/C1CCC(\\C)CC1', 'c1cnc2c(c1)ccc3ncccc23', 'COC(C)(C)C',
#        'COc1ccc(C=CC)cc1', 'CCCCCCCCCCCCCCCCO', 'O=c1cc[nH]c(=O)[nH]1',
#        'Nc1ncnc2nc[nH]c12', 'Clc1cc(Cl)c(cc1Cl)c2cccc(Cl)c2Cl',
#        'COc1ccc(cc1)C(O)(C2CC2)c3cncnc3',
#        'c1ccc2c(c1)c3cccc4c3c2cc5ccccc54', 'O=C(Nc1ccccc1)Nc2ccccc2',
#        'CCC1(C(=O)NC(=O)NC1=O)c2ccccc2', 'Clc1ccc(cc1)c2cccc(Cl)c2Cl',
#        'CC(C)c1ccc(NC(=O)N(C)C)cc1', 'CCN(CC)C(=O)CSc1ccc(Cl)nn1',
#        'CCC(C)(C)CO', 'CCCOC(=O)CCC',
#        'Cc1c(cc(cc1N(=O)=O)N(=O)=O)N(=O)=O',
#        'CC(C)OP(=S)(OC(C)C)SCCNS(=O)(=O)c1ccccc1', 'C1CCCCCC1', 'CCCOC=O',
#        'CC(C)c1ccccc1C', 'Nc1cccc(Cl)c1', 'CC(C)CC(C)C',
#        'o1c2ccccc2c3ccccc13', 'CCOC2Oc1ccc(OS(C)(=O)=O)cc1C2(C)C',
#        'CN(C)C(=O)Nc1cccc(c1)C(F)(F)F', 'c3ccc2nc1ccccc1cc2c3',
#        'CC12CC(=O)C3C(CCC4=CC(=O)CCC34C)C2CCC1(O)C(=O)CO',
#        'OCC1OC(O)C(O)C(O)C1O', 'Cc1cccc(O)c1',
#        'CC2Cc1ccccc1N2NC(=O)c3ccc(Cl)c(c3)S(N)(=O)=O',
#        'CCC(C)C(=O)OC2CC(C)C=C3C=CC(C)C(CCC1CC(O)CC(=O)O1)C23',
#        'O=N(=O)c1ccc(cc1)N(=O)=O', 'CCC1(C(=O)NC(=O)NC1=O)C2=CCC3CCC2C3',
#        'CCCCCCCCCC(=O)OCC', 'CN(C)C(=O)Nc1ccccc1', 'CCCOCC', 'CC(C)O',
#        'Cc1ccc2ccccc2c1', 'ClC(Br)Br', 'CCC(C(CC)c1ccc(O)cc1)c2ccc(O)cc2',
#        'CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC', 'ClCc1ccccc1', 'C/C=C/C=O',
#        'CON(C)C(=O)Nc1ccc(Br)c(Cl)c1', 'Cc1c2ccccc2c(C)c3ccccc13',
#        'CCCCCC(=O)OC', 'CN(C)C(=O)Nc1ccc(c(Cl)c1)n2nc(oc2=O)C(C)(C)C',
#        'CC(=O)Nc1ccc(F)cc1', 'CCc1cccc(CC)c1N(COC)C(=O)CCl', 'C1CCC=CC1',
#        'CC12CC(O)C3C(CCC4=CC(=O)CCC34C)C2CCC1(O)C(=O)CO', 'c1cncnc1',
#        'Clc1ccc(cc1)N(=O)=O', 'CCC(=O)OC', 'Clc1ccccc1N(=O)=O',
#        'CCCCN(C)C(=O)Nc1ccc(Cl)c(Cl)c1',
#        'CN1CC(O)N(C1=O)c2nnc(s2)C(C)(C)C', 'O=N(=O)c1ccccc1', 'Ic1ccccc1',
#        'CC2Nc1cc(Cl)c(cc1C(=O)N2c3ccccc3C)S(N)(=O)=O',
#        'COc1ccccc1OCC(O)COC(N)=O', 'CCCCOCN(C(=O)CCl)c1c(CC)cccc1CC',
#        'Oc1cccc(Cl)c1Cl', 'CCCC(=O)OC', 'CCC(=O)Nc1ccc(Cl)c(Cl)c1',
#        'Nc3nc(N)c2nc(c1ccccc1)c(N)nc2n3', 'CCCCCC(=O)OCC',
#        'OCC(O)C2OC1OC(OC1C2O)C(Cl)(Cl)Cl',
#        'CN(C=Nc1ccc(C)cc1C)C=Nc2ccc(C)cc2C', 'COc1nc(NC(C)C)nc(NC(C)C)n1',
#        'CCCCCCC=C', 'Cc1ccc(N)cc1', 'Nc1nccs1', 'c1ccccc1(OC(=O)NC)',
#        'CCCC(O)CC', 'c3ccc2c(O)c1ccccc1cc2c3', 'Cc1ccc2cc3ccccc3cc2c1',
#        'Cc1cccc(C)c1C', 'CNC(=O)Oc1ccc(N(C)C)c(C)c1', 'CCCCCCCC(C)O',
#        'CN(C(=O)NC(C)(C)c1ccccc1)c2ccccc2', 'CCCC(=O)CC',
#        'Oc1c(Br)cc(C#N)cc1Br', 'Clc1ccc(cc1Cl)c2ccccc2',
#        'CN(C(=O)COc1nc2ccccc2s1)c3ccccc3', 'Oc1cccc2ncccc12',
#        'CC1=C(SCCO1)C(=O)Nc2ccccc2', 'CCOc2ccc1nc(sc1c2)S(N)(=O)=O',
#        'Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl', 'ClCBr',
#        'CCC1(CC)C(=O)NC(=O)N(C)C1=O',
#        'CC(=O)OCC(=O)C3CCC4C2CCC1=CC(=O)CCC1(C)C2CCC34C',
#        'NC(=O)NCc1ccccc1', 'CN(C)C(=O)Nc1ccc(C)c(Cl)c1',
#        'CON(C)C(=O)Nc1ccc(Cl)c(Cl)c1', 'OC1CCCCCC1',
#        'CS(=O)(=O)c1ccc(cc1)C(O)C(CO)NC(=O)C(Cl)Cl',
#        'CCCC(C)C1(CC)C(=O)NC(=S)NC1=O', 'CC(=O)Nc1nnc(s1)S(N)(=O)=O',
#        'Oc1ccc(cc1)N(=O)=O',
#        'ClC1=C(Cl)C2(Cl)C3C4CC(C=C4)C3C1(Cl)C2(Cl)Cl', 'C1CCOC1',
#        'Nc1ccccc1N(=O)=O', 'Clc1cccc(c1Cl)c2cccc(Cl)c2Cl',
#        'CCCCC1C(=O)N(N(C1=O)c2ccccc2)c3ccccc3',
#        'Cc1c(cccc1N(=O)=O)N(=O)=O',
#        'CC(=O)C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C',
#        'CCN(CC)c1nc(Cl)nc(n1)N(CC)CC',
#        'ClC(Cl)C(Cl)(Cl)SN2C(=O)C1CC=CCC1C2=O', 'c1(Br)c(Br)cc(Br)cc1',
#        'OC3N=C(c1ccccc1)c2cc(Cl)ccc2NC3=O',
#        'O=C1NC(=O)NC(=O)C1(C(C)CCC)CC=C', 'c1(O)c(C)ccc(C(C)C)c1',
#        'C1SC(=S)NC1(=O)', 'Oc1ccc(c(O)c1)c3oc2cc(O)cc(O)c2c(=O)c3O',
#        'ClC1(C(=O)C2(Cl)C3(Cl)C14Cl)C5(Cl)C2(Cl)C3(Cl)C(Cl)(Cl)C45Cl',
#        'CCN(CC)C(=S)SSC(=S)N(CC)CC', 'C1CCCCC1',
#        'ClC1=C(Cl)C(Cl)(C(=C1Cl)Cl)C2(Cl)C(=C(Cl)C(=C2Cl)Cl)Cl',
#        'CN(C)C=Nc1ccc(Cl)cc1C', 'CC34CCc1c(ccc2cc(O)ccc12)C3CCC4=O',
#        'CCCCCCCCO', 'CCSCC', 'ClCCCl', 'CCC(C)(C)Cl', 'ClCCBr',
#        'Nc1ccc(cc1)N(=O)=O', 'OCC1OC(OC2C(O)C(O)C(O)OC2CO)C(O)C(O)C1O',
#        'CCN2c1ncccc1N(CC)C(=O)c3cccnc23', 'Clc1ccccc1', 'CCCCCCCC=C',
#        'Brc1ccc(I)cc1', 'CCC(C)(O)CC', 'CCCCCc1ccccc1',
#        'NC(=O)NC1NC(=O)NC1=O', 'OCC(O)COC(=O)c1ccccc1Nc2ccnc3cc(Cl)ccc23',
#        'ClC(Cl)C(c1ccc(Cl)cc1)c2ccc(Cl)cc2',
#        'CC(=O)OC3CCC4C2CCC1=CC(=O)CCC1(C)C2CCC34C', 'Clc1cccc2ccccc12',
#        'CCN2c1ccccc1N(C)C(=O)c3ccccc23', 'CCCCC(C)O', 'CCCC1CCCC1',
#        'CCOC(=O)c1cncn1C(C)c2ccccc2', 'Oc1ccc(Cl)c(Cl)c1',
#        'CC1(C)C(C=C(Cl)Cl)C1C(=O)OC(C#N)c2cccc(Oc3ccccc3)c2',
#        'c2ccc1ocnc1c2', 'CCCCCO', 'CCN(CC)c1ccccc1', 'Fc1cccc(F)c1',
#        'ClCCC#N', 'CC(C)(C)Cc1ccccc1', 'O=C1NC(=O)NC(=O)C1(CC)c1ccccc1',
#        'Clc1ccccc1I', 'c2ccc1[nH]nnc1c2', 'CNC(=O)Oc1cccc2CC(C)(C)Oc12',
#        'Cc1cccc(C)c1O', 'CC(C)C(C)O', 'c1ccccc1C(O)c2ccccc2',
#        'CCCCCCCCCC(=O)OC', 'COP(=S)(OC)Oc1ccc(cc1Cl)N(=O)=O', 'CC(C)CBr',
#        'CCI', 'CN(C)C(=O)Oc1nc(nc(C)c1C)N(C)C', 'CCCCCCBr', 'CCCC(C)C',
#        'Cc1c(F)c(F)c(COC(=O)C2C(C=C(Cl)C(F)(F)F)C2(C)C)c(F)c1F',
#        'CCc1cccc(C)c1N(C(C)COC)C(=O)CCl', 'ON=Cc1ccc(o1)N(=O)=O',
#        'CC(C)C(Nc1ccc(cc1Cl)C(F)(F)F)C(=O)OC(C#N)c2cccc(Oc3ccccc3)c2',
#        'Nc1nc[nH]n1', 'BrC(Br)Br', 'COP(=O)(OC)C(O)C(Cl)(Cl)Cl',
#        'CCOP(=S)(OCC)SCn1c(=O)oc2cc(Cl)ccc12', 'OCc1ccccc1',
#        'O=c2c(C3CCCc4ccccc43)c(O)c1ccccc1o2', 'Oc1ccc(Br)cc1', 'CC(C)Br',
#        'CC(C)CC(C)(C)C', 'O=N(=O)c1cc(cc(c1)N(=O)=O)N(=O)=O',
#        'CN2C(=O)CN=C(c1ccccc1)c3cc(ccc23)N(=O)=O', 'CCC',
#        'Nc1cc(nc(N)n1=O)N2CCCCC2', 'Nc2cccc3nc1ccccc1cc23',
#        'c1ccc2cc3c4cccc5cccc(c3cc2c1)c45',
#        'OC(c1ccc(Cl)cc1)(c2ccc(Cl)cc2)C(Cl)(Cl)Cl', 'C1Cc2cccc3cccc1c23'],
#       dtype=object)

# %%
ys
# Out:
# array([[-0.77 ],
#        [-3.3  ],
#        [-2.06 ],
#        [-7.87 ],
#        [-1.33 ],
#        [-1.5  ],
#        [-7.32 ],
#        [-5.03 ],
#        [-6.29 ],
#        [-4.42 ],
#        [ 1.07 ],
#        [-4.14 ],
#        [-2.68 ],
#        [-2.64 ],
#        [-7.96 ],
#        [-1.41 ],
#        [-0.47 ],
#        [-1.   ],
#        [-3.64 ],
#        [-2.94 ],
#        [-7.43 ],
#        [-4.594],
#        [-4.11 ],
#        [-2.35 ],
#        [-5.47 ],
#        [-1.81 ],
#        [-1.39 ],
#        [-1.661],
#        [-6.9  ],
#        [-3.17 ],
#        [-3.75 ],
#        [-4.755],
#        [-4.805],
#        [-1.64 ],
#        [-5.22 ],
#        [-0.85 ],
#        [-3.504],
#        [-3.927],
#        [-4.15 ],
#        [-4.81 ],
#        [-4.88 ],
#        [-0.15 ],
#        [-1.655],
#        [-2.53 ],
#        [-0.63 ],
#        [-1.55 ],
#        [-3.083],
#        [-3.127],
#        [-4.76 ],
#        [-1.94 ],
#        [-3.66 ],
#        [-2.17 ],
#        [-8.057],
#        [-2.523],
#        [-8.6  ],
#        [-0.62 ],
#        [-5.05 ],
#        [-4.14 ],
#        [-6.57 ],
#        [-0.19 ],
#        [-9.15 ],
#        [-0.82 ],
#        [-3.68 ],
#        [-0.8  ],
#        [-2.81 ],
#        [-5.931],
#        [-4.06 ],
#        [-0.667],
#        [-2.68 ],
#        [-5.27 ],
#        [-3.38 ],
#        [-5.46 ],
#        [-1.96 ],
#        [-2.369],
#        [-2.25 ],
#        [-1.92 ],
#        [-5.886],
#        [-6.01 ],
#        [-1.73 ],
#        [-3.493],
#        [-1.995],
#        [-0.466],
#        [ 0.32 ],
#        [-2.77 ],
#        [-3.28 ],
#        [-3.67 ],
#        [-6.876],
#        [-0.8  ],
#        [-2.35 ],
#        [-5.36 ],
#        [-3.48 ],
#        [-3.46 ],
#        [-6.   ],
#        [-1.34 ],
#        [-4.29 ],
#        [-4.07 ],
#        [-5.64 ],
#        [-7.25 ],
#        [-1.6  ],
#        [-3.27 ],
#        [-3.45 ],
#        [-5.43 ],
#        [ 0.39 ],
#        [-0.63 ],
#        [-4.17 ],
#        [ 0.58 ],
#        [-1.74 ],
#        [-1.506],
#        [-2.55 ],
#        [-1.23 ],
#        [-3.61 ],
#        [-4.7  ],
#        [-3.18 ],
#        [ 0.   ],
#        [-5.17 ],
#        [-2.523],
#        [-1.45 ],
#        [-4.432],
#        [-5.21 ],
#        [-4.54 ],
#        [-3.03 ],
#        [-4.8  ],
#        [-5.65 ],
#        [-1.01 ],
#        [-5.51 ],
#        [-0.6  ],
#        [-2.24 ],
#        [-7.337],
#        [ 0.76 ],
#        [-4.43 ],
#        [ 0.36 ],
#        [-3.43 ],
#        [-2.09 ],
#        [-0.82 ],
#        [-4.26 ],
#        [-3.04 ],
#        [-2.41 ],
#        [-1.886],
#        [-3.55 ],
#        [-4.35 ],
#        [-2.54 ],
#        [ 0.45 ],
#        [-1.96 ],
#        [-1.92 ],
#        [-2.82 ],
#        [-1.947],
#        [ 1.57 ],
#        [-2.468],
#        [ 0.52 ],
#        [-1.077],
#        [-1.95 ],
#        [ 0.81 ],
#        [-1.24 ],
#        [-2.73 ],
#        [-1.87 ],
#        [-0.72 ],
#        [-1.99 ],
#        [-0.02 ],
#        [-6.62 ],
#        [-3.08 ],
#        [-2.253],
#        [-6.01 ],
#        [-1.3  ],
#        [-3.082],
#        [-3.043],
#        [-2.46 ],
#        [-5.28 ],
#        [-6.523],
#        [-0.22 ],
#        [-6.124],
#        [-4.57 ],
#        [-1.807],
#        [-4.65 ],
#        [-1.   ],
#        [-1.13 ],
#        [-6.301],
#        [-1.06 ],
#        [-2.39 ],
#        [-2.58 ],
#        [-2.337],
#        [-3.68 ],
#        [-8.6  ],
#        [-2.925],
#        [-0.092],
#        [-5.752],
#        [-5.66 ],
#        [ 1.1  ],
#        [-4.63 ],
#        [-7.32 ],
#        [-0.72 ],
#        [-3.8  ],
#        [-1.601],
#        [-2.05 ],
#        [-1.96 ],
#        [-2.28 ],
#        [-5.696],
#        [-2.36 ],
#        [-4.24 ],
#        [-3.52 ],
#        [-1.1  ],
#        [-3.094],
#        [ 1.34 ],
#        [-0.41 ],
#        [-4.862],
#        [-3.408],
#        [ 0.57 ],
#        [-2.296],
#        [-2.16 ],
#        [-1.8  ],
#        [-1.47 ],
#        [-0.04 ],
#        [-4.36 ],
#        [-4.   ],
#        [-1.64 ],
#        [-3.896],
#        [-6.56 ],
#        [ 0.38 ],
#        [-2.06 ],
#        [-5.736],
#        [-3.571],
#        [-8.804],
#        [-2.82 ],
#        [-4.4  ],
#        [-2.34 ],
#        [-1.139],
#        [-3.19 ],
#        [-3.658],
#        [-2.03 ],
#        [-1.99 ],
#        [-4.57 ],
#        [-0.44 ],
#        [-1.16 ],
#        [-4.16 ],
#        [ 0.06 ],
#        [-4.62 ],
#        [-3.85 ],
#        [-1.77 ],
#        [-1.3  ],
#        [-0.72 ],
#        [-0.7  ],
#        [-0.6  ],
#        [-0.85 ],
#        [-2.168],
#        [-4.046],
#        [-3.3  ],
#        [-3.785],
#        [-2.616],
#        [-3.59 ],
#        [-4.09 ],
#        [ 0.62 ],
#        [-2.62 ],
#        [-0.45 ],
#        [-2.23 ],
#        [ 0.85 ],
#        [-5.35 ],
#        [-1.22 ],
#        [-3.6  ],
#        [-1.7  ],
#        [-4.097],
#        [-7.02 ],
#        [-6.34 ],
#        [-6.89 ],
#        [-7.28 ],
#        [-4.678],
#        [-2.89 ],
#        [-3.37 ],
#        [-4.13 ],
#        [-2.37 ],
#        [-6.98 ],
#        [-0.74 ],
#        [-3.4  ],
#        [-2.78 ],
#        [-8.402],
#        [-2.016],
#        [-4.04 ],
#        [-4.55 ],
#        [ 1.09 ],
#        [-0.6  ],
#        [-1.48 ],
#        [-2.09 ],
#        [-1.82 ],
#        [-2.33 ],
#        [-2.766],
#        [-3.21 ],
#        [-4.   ],
#        [-2.4  ],
#        [-4.62 ],
#        [-1.74 ],
#        [-5.153],
#        [-5.84 ],
#        [-4.4  ],
#        [-4.02 ],
#        [ 0.523],
#        [-5.282],
#        [-4.576],
#        [-2.41 ],
#        [-3.12 ],
#        [-9.16 ],
#        [-0.41 ],
#        [-8.334],
#        [-3.324],
#        [-1.29 ],
#        [-1.34 ],
#        [-6.49 ],
#        [-4.64 ],
#        [-4.194],
#        [-4.   ],
#        [-2.31 ],
#        [-3.2  ],
#        [-1.29 ],
#        [-3.999],
#        [-2.17 ],
#        [-4.47 ],
#        [-2.68 ],
#        [-0.24 ],
#        [-3.13 ],
#        [-7.   ],
#        [-1.488],
#        [-2.12 ],
#        [-7.21 ],
#        [-2.596],
#        [-8.23 ],
#        [-3.15 ],
#        [-2.322],
#        [-6.29 ],
#        [-3.536],
#        [-1.716],
#        [-1.04 ],
#        [-1.75 ],
#        [-3.22 ],
#        [-4.2  ],
#        [-3.51 ],
#        [-0.49 ],
#        [-3.76 ],
#        [-1.37 ],
#        [-4.26 ],
#        [-4.6  ],
#        [-3.42 ],
#        [-3.43 ],
#        [-3.67 ],
#        [-3.11 ],
#        [ 0.74 ],
#        [-0.68 ],
#        [-3.586],
#        [-6.005],
#        [-3.39 ],
#        [-2.696],
#        [-4.1  ],
#        [-1.6  ],
#        [-0.66 ],
#        [ 0.43 ],
#        [-3.77 ],
#        [-1.9  ],
#        [-4.43 ],
#        [-3.37 ],
#        [-2.39 ],
#        [ 0.32 ],
#        [-3.924],
#        [-6.57 ],
#        [-1.87 ],
#        [-4.328],
#        [-1.78 ],
#        [-3.26 ],
#        [-2.59 ],
#        [-3.09 ],
#        [ 1.1  ],
#        [-2.92 ],
#        [-0.14 ],
#        [-2.55 ],
#        [-4.77 ],
#        [-1.877],
#        [-1.8  ],
#        [-3.01 ],
#        [-3.78 ],
#        [-0.985],
#        [-4.19 ],
#        [-1.3  ],
#        [-1.92 ],
#        [-3.   ],
#        [-2.404],
#        [-2.35 ],
#        [-1.84 ],
#        [-5.47 ],
#        [-2.478],
#        [-4.44 ],
#        [-1.21 ],
#        [-0.36 ],
#        [-1.803],
#        [-0.8  ],
#        [-4.73 ],
#        [-6.96 ],
#        [-3.2  ],
#        [-2.36 ],
#        [-2.74 ],
#        [-3.35 ],
#        [-0.83 ],
#        [-3.33 ],
#        [-6.39 ],
#        [-4.873],
#        [-2.54 ],
#        [-3.14 ],
#        [-3.81 ],
#        [-4.28 ],
#        [-0.89 ],
#        [-2.23 ],
#        [-4.63 ],
#        [-0.95 ],
#        [-3.483],
#        [-3.592],
#        [-0.88 ],
#        [-2.154],
#        [-3.36 ],
#        [-2.36 ],
#        [-0.74 ],
#        [-6.307],
#        [ 0.49 ],
#        [-1.96 ],
#        [-7.28 ],
#        [-3.81 ],
#        [-3.   ],
#        [-4.42 ],
#        [-4.411],
#        [-5.4  ],
#        [-4.5  ],
#        [-3.952],
#        [-2.356],
#        [-2.08 ],
#        [-1.77 ],
#        [-3.083],
#        [-5.259],
#        [-4.86 ],
#        [-3.1  ],
#        [-7.278],
#        [-2.86 ],
#        [-5.24 ],
#        [-2.39 ],
#        [-1.34 ],
#        [-1.06 ],
#        [-2.51 ],
#        [-1.32 ],
#        [-2.37 ],
#        [-0.244],
#        [-2.86 ],
#        [-2.38 ],
#        [-5.05 ],
#        [-4.56 ],
#        [-0.36 ],
#        [-4.64 ],
#        [-1.6  ],
#        [-4.571],
#        [-7.2  ],
#        [-5.184],
#        [-3.93 ],
#        [-4.749],
#        [-0.89 ],
#        [-4.74 ],
#        [-4.735],
#        [-1.25 ],
#        [-8.017],
#        [-1.16 ],
#        [-0.6  ],
#        [-3.03 ],
#        [-2.   ],
#        [-0.29 ],
#        [-4.15 ],
#        [-2.322],
#        [-3.54 ],
#        [-0.78 ],
#        [-2.8  ],
#        [-1.29 ],
#        [-0.18 ],
#        [-2.55 ],
#        [-4.69 ],
#        [-4.31 ],
#        [-2.43 ],
#        [-1.6  ],
#        [-1.95 ],
#        [-3.81 ],
#        [-3.74 ],
#        [-7.321],
#        [-2.73 ],
#        [-2.19 ],
#        [-8.003],
#        [ 0.522],
#        [-1.91 ],
#        [-0.22 ],
#        [-5.233],
#        [-0.4  ],
#        [-2.84 ],
#        [-1.09 ],
#        [-1.59 ],
#        [-4.74 ],
#        [-2.89 ],
#        [-3.796],
#        [-1.94 ],
#        [-1.989],
#        [-4.22 ],
#        [-8.49 ],
#        [-5.666],
#        [-4.63 ]])

# %% [markdown]
# # Get datapoints

# %%
real_data = [ data.MoleculeDatapoint.from_smi (smi, y) for smi, y in zip(smles, ys)]
real_data [0]
# Out:
# MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685A3ED0>, y=array([-0.77]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)C(O)C3O', V_f=None, E_f=None, V_d=None)

# %% [markdown]
# # Train, test, valid split

# %%
mols =[ d.mol for d in real_data ] # Create RDkit objects to perform structure based split => Prevents that the sets containing similar molecules
mols
# Out:
# [<rdkit.Chem.rdchem.Mol at 0x1bc685a3ed0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685a3bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685a3d80>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685a3610>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685a3e60>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685a34c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685a0740>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685df0d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685df1b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684eff40>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684edb60>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684edc40>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684edd20>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684ede00>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684edee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684edfc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684ee0a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684ee180>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684ee2d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684ee420>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684ee500>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684ee5e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc684ed9a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685506d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685507b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68550890>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68550970>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68550a50>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68550b30>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68550c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68550cf0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68550dd0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68550eb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68550f90>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551070>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551150>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551230>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551310>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685513f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685514d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685515b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551690>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551770>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551850>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551930>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551a10>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551af0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551bd0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551d90>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551e70>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68551f50>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552030>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552110>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685521f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685522d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685523b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552490>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552570>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552650>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552730>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552810>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685528f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685529d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552ab0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552b90>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552c70>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552e30>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552f10>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68552ff0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685530d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685531b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553290>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553370>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553450>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553530>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553610>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685536f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685537d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685538b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553990>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553a70>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553b50>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553c30>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553d10>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68553ed0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520040>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520120>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520200>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685202e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685203c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685204a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520580>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520660>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520740>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520820>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520900>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685209e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520ac0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520ba0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520c80>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520d60>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68520f20>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521000>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685210e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685211c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685212a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521380>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521460>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521540>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521620>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521700>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685217e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685218c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685219a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521b60>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521c40>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521d20>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521e00>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68521fc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685220a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522180>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522260>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522340>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522420>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522500>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685225e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685226c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685227a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522880>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522960>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522a40>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522c00>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522ce0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522dc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522ea0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68522f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523060>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523140>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523220>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523300>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685233e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685234c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685235a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523680>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523760>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523840>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523920>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523a00>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523ae0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523ca0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523d80>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523e60>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68523f40>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685640b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564190>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564270>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564350>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564430>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564510>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685645f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685646d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685647b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564890>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564970>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564a50>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564b30>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564cf0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564dd0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564eb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68564f90>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565070>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565150>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565230>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565310>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685653f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685654d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685655b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565690>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565770>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565850>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565930>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565a10>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565af0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565bd0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565d90>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565e70>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68565f50>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68566030>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68566110>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685661f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685662d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc685663b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc68566490>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc
e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1bc6857e6c0>]

# %%
# Here indices are obteined for each group
train_indices, val_indices, test_indices = data.make_split_indices(mols, "random", (0.8,0.1,0.1))
train_indices
# Out:
# The return type of make_split_indices has changed in v2.1 - see help(make_split_indices)
# [[np.int64(254),
#   np.int64(283),
#   np.int64(445),
#   np.int64(461),
#   np.int64(15),
#   np.int64(316),
#   np.int64(489),
#   np.int64(159),
#   np.int64(153),
#   np.int64(241),
#   np.int64(250),
#   np.int64(390),
#   np.int64(289),
#   np.int64(171),
#   np.int64(329),
#   np.int64(468),
#   np.int64(355),
#   np.int64(154),
#   np.int64(37),
#   np.int64(205),
#   np.int64(366),
#   np.int64(240),
#   np.int64(108),
#   np.int64(45),
#   np.int64(438),
#   np.int64(21),
#   np.int64(367),
#   np.int64(96),
#   np.int64(233),
#   np.int64(428),
#   np.int64(118),
#   np.int64(124),
#   np.int64(191),
#   np.int64(374),
#   np.int64(492),
#   np.int64(311),
#   np.int64(451),
#   np.int64(353),
#   np.int64(238),
#   np.int64(322),
#   np.int64(46),
#   np.int64(403),
#   np.int64(221),
#   np.int64(76),
#   np.int64(1),
#   np.int64(213),
#   np.int64(325),
#   np.int64(418),
#   np.int64(102),
#   np.int64(363),
#   np.int64(170),
#   np.int64(343),
#   np.int64(144),
#   np.int64(132),
#   np.int64(12),
#   np.int64(327),
#   np.int64(173),
#   np.int64(224),
#   np.int64(342),
#   np.int64(78),
#   np.int64(276),
#   np.int64(387),
#   np.int64(425),
#   np.int64(301),
#   np.int64(196),
#   np.int64(10),
#   np.int64(469),
#   np.int64(271),
#   np.int64(75),
#   np.int64(142),
#   np.int64(65),
#   np.int64(340),
#   np.int64(484),
#   np.int64(175),
#   np.int64(362),
#   np.int64(264),
#   np.int64(100),
#   np.int64(491),
#   np.int64(295),
#   np.int64(300),
#   np.int64(235),
#   np.int64(475),
#   np.int64(219),
#   np.int64(330),
#   np.int64(326),
#   np.int64(421),
#   np.int64(157),
#   np.int64(348),
#   np.int64(54),
#   np.int64(220),
#   np.int64(402),
#   np.int64(379),
#   np.int64(200),
#   np.int64(179),
#   np.int64(372),
#   np.int64(56),
#   np.int64(440),
#   np.int64(60),
#   np.int64(208),
#   np.int64(107),
#   np.int64(336),
#   np.int64(71),
#   np.int64(474),
#   np.int64(6),
#   np.int64(412),
#   np.int64(113),
#   np.int64(236),
#   np.int64(299),
#   np.int64(155),
#   np.int64(272),
#   np.int64(7),
#   np.int64(137),
#   np.int64(8),
#   np.int64(463),
#   np.int64(432),
#   np.int64(375),
#   np.int64(284),
#   np.int64(210),
#   np.int64(188),
#   np.int64(430),
#   np.int64(49),
#   np.int64(134),
#   np.int64(365),
#   np.int64(413),
#   np.int64(239),
#   np.int64(59),
#   np.int64(406),
#   np.int64(391),
#   np.int64(411),
#   np.int64(485),
#   np.int64(229),
#   np.int64(297),
#   np.int64(55),
#   np.int64(293),
#   np.int64(490),
#   np.int64(458),
#   np.int64(457),
#   np.int64(453),
#   np.int64(186),
#   np.int64(194),
#   np.int64(52),
#   np.int64(74),
#   np.int64(26),
#   np.int64(488),
#   np.int64(4),
#   np.int64(318),
#   np.int64(331),
#   np.int64(245),
#   np.int64(5),
#   np.int64(141),
#   np.int64(383),
#   np.int64(135),
#   np.int64(493),
#   np.int64(122),
#   np.int64(22),
#   np.int64(68),
#   np.int64(20),
#   np.int64(382),
#   np.int64(14),
#   np.int64(278),
#   np.int64(225),
#   np.int64(64),
#   np.int64(381),
#   np.int64(231),
#   np.int64(81),
#   np.int64(401),
#   np.int64(302),
#   np.int64(499),
#   np.int64(471),
#   np.int64(455),
#   np.int64(160),
#   np.int64(478),
#   np.int64(364),
#   np.int64(496),
#   np.int64(206),
#   np.int64(319),
#   np.int64(51),
#   np.int64(306),
#   np.int64(452),
#   np.int64(332),
#   np.int64(164),
#   np.int64(106),
#   np.int64(481),
#   np.int64(63),
#   np.int64(344),
#   np.int64(427),
#   np.int64(439),
#   np.int64(320),
#   np.int64(89),
#   np.int64(312),
#   np.int64(450),
#   np.int64(93),
#   np.int64(298),
#   np.int64(459),
#   np.int64(308),
#   np.int64(395),
#   np.int64(92),
#   np.int64(18),
#   np.int64(198),
#   np.int64(145),
#   np.int64(158),
#   np.int64(150),
#   np.int64(479),
#   np.int64(167),
#   np.int64(255),
#   np.int64(230),
#   np.int64(422),
#   np.int64(66),
#   np.int64(309),
#   np.int64(253),
#   np.int64(140),
#   np.int64(101),
#   np.int64(433),
#   np.int64(2),
#   np.int64(408),
#   np.int64(17),
#   np.int64(146),
#   np.int64(249),
#   np.int64(263),
#   np.int64(30),
#   np.int64(114),
#   np.int64(247),
#   np.int64(103),
#   np.int64(405),
#   np.int64(310),
#   np.int64(176),
#   np.int64(246),
#   np.int64(116),
#   np.int64(168),
#   np.int64(415),
#   np.int64(120),
#   np.int64(261),
#   np.int64(112),
#   np.int64(360),
#   np.int64(435),
#   np.int64(282),
#   np.int64(136),
#   np.int64(190),
#   np.int64(347),
#   np.int64(181),
#   np.int64(126),
#   np.int64(281),
#   np.int64(252),
#   np.int64(407),
#   np.int64(393),
#   np.int64(354),
#   np.int64(232),
#   np.int64(133),
#   np.int64(33),
#   np.int64(476),
#   np.int64(162),
#   np.int64(34),
#   np.int64(44),
#   np.int64(97),
#   np.int64(85),
#   np.int64(61),
#   np.int64(199),
#   np.int64(268),
#   np.int64(218),
#   np.int64(73),
#   np.int64(35),
#   np.int64(303),
#   np.int64(29),
#   np.int64(361),
#   np.int64(392),
#   np.int64(443),
#   np.int64(217),
#   np.int64(27),
#   np.int64(399),
#   np.int64(380),
#   np.int64(156),
#   np.int64(429),
#   np.int64(345),
#   np.int64(138),
#   np.int64(212),
#   np.int64(104),
#   np.int64(350),
#   np.int64(346),
#   np.int64(351),
#   np.int64(215),
#   np.int64(385),
#   np.int64(189),
#   np.int64(214),
#   np.int64(204),
#   np.int64(234),
#   np.int64(259),
#   np.int64(67),
#   np.int64(24),
#   np.int64(216),
#   np.int64(223),
#   np.int64(129),
#   np.int64(111),
#   np.int64(166),
#   np.int64(417),
#   np.int64(394),
#   np.int64(40),
#   np.int64(274),
#   np.int64(357),
#   np.int64(79),
#   np.int64(313),
#   np.int64(315),
#   np.int64(13),
#   np.int64(287),
#   np.int64(409),
#   np.int64(494),
#   np.int64(228),
#   np.int64(161),
#   np.int64(83),
#   np.int64(497),
#   np.int64(473),
#   np.int64(110),
#   np.int64(149),
#   np.int64(152),
#   np.int64(16),
#   np.int64(339),
#   np.int64(109),
#   np.int64(352),
#   np.int64(139),
#   np.int64(237),
#   np.int64(260),
#   np.int64(419),
#   np.int64(317),
#   np.int64(495),
#   np.int64(400),
#   np.int64(248),
#   np.int64(386),
#   np.int64(19),
#   np.int64(328),
#   np.int64(296),
#   np.int64(269),
#   np.int64(226),
#   np.int64(414),
#   np.int64(3),
#   np.int64(378),
#   np.int64(125),
#   np.int64(280),
#   np.int64(286),
#   np.int64(77),
#   np.int64(184),
#   np.int64(424),
#   np.int64(477),
#   np.int64(275),
#   np.int64(294),
#   np.int64(436),
#   np.int64(182),
#   np.int64(447),
#   np.int64(80),
#   np.int64(307),
#   np.int64(258),
#   np.int64(11),
#   np.int64(371),
#   np.int64(86),
#   np.int64(266),
#   np.int64(36),
#   np.int64(480),
#   np.int64(58),
#   np.int64(41),
#   np.int64(270),
#   np.int64(50),
#   np.int64(209),
#   np.int64(397),
#   np.int64(410),
#   np.int64(416),
#   np.int64(123),
#   np.int64(222),
#   np.int64(62),
#   np.int64(377),
#   np.int64(130),
#   np.int64(187),
#   np.int64(23),
#   np.int64(43),
#   np.int64(441),
#   np.int64(0),
#   np.int64(201),
#   np.int64(368),
#   np.int64(426),
#   np.int64(98),
#   np.int64(349),
#   np.int64(304),
#   np.int64(487),
#   np.int64(178),
#   np.int64(369),
#   np.int64(256),
#   np.int64(94),
#   np.int64(465),
#   np.int64(95),
#   np.int64(442),
#   np.int64(169),
#   np.int64(69),
#   np.int64(305),
#   np.int64(48),
#   np.int64(341),
#   np.int64(373),
#   np.int64(207),
#   np.int64(279),
#   np.int64(227),
#   np.int64(148),
#   np.int64(143),
#   np.int64(334),
#   np.int64(180)]]

# %%
# Splitting the dataset using this indices
train_data, val_data, test_data = data.split_data_by_indices(
    real_data, train_indices, val_indices, test_indices
)
train_data
# Out:
# [[MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685C52A0>, y=array([-5.35]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CC(=O)OC3(CCC4C2C=C(C)C1=CC(=O)CCC1(C)C2CCC34C)C(C)=O', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685C6C00>, y=array([-3.21]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCc1ccccc1C', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685636F0>, y=array([-4.56]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Brc1ccc(I)cc1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC6857C580>, y=array([-3.03]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCN(CC)c1ccccc1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC684EDFC0>, y=array([-1.41]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CC(C)Cl', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685D0580>, y=array([-7.]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCCCCCCCCCCCCCCCO', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC6857DE00>, y=array([-1.09]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Oc1ccc(Br)cc1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68523E60>, y=array([-3.08]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Cc1ccc(Cl)cc1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68523920>, y=array([-2.73]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCCCCCl', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685C4740>, y=array([-0.85]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Cc1cccc(N)c1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685C4F20>, y=array([-2.62]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCN2c1ncccc1N(C)C(=O)c3cccnc23', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685606D0>, y=array([-6.96]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Cc1ccc2cc3ccccc3cc2c1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685C7140>, y=array([-5.84]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Cc1ccc2c(ccc3ccccc32)c1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68564970>, y=array([-1.807]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCCC(C)(COC(N)=O)COC(N)=O', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685D10E0>, y=array([-3.22]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Cc1c(cc(cc1N(=O)=O)N(=O)=O)N(=O)=O', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC6857CBA0>, y=array([-2.8]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CNC(=O)Oc1cccc2CC(C)(C)Oc12', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685D27A0>, y=array([-2.39]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name
), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCCCN(C)C(=O)Nc1ccc(Cl)c(Cl)c1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685C5460>, y=array([-3.6]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='c1ccc2ccccc2c1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68520580>, y=array([-4.29]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Cc1cc(C)c2ccccc2c1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC6857C900>, y=array([-2.322]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='O=C1NC(=O)NC(=O)C1(CC)c1ccccc1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68520660>, y=array([-4.07]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCC(=C(CC)c1ccc(O)cc1)c2ccc(O)cc2', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68563450>, y=array([-2.86]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCN2c1ncccc1N(CC)C(=O)c3cccnc23', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685647B0>, y=array([-6.124]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCN(CC(C)=C)c1c(cc(cc1N(=O)=O)C(F)(F)F)N(=O)=O', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68552F10>, y=array([-5.27]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Clc1ccccc1c2ccccc2Cl', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685A06D0>, y=array([-4.194]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCOP(=S)(NC(C)C)Oc1ccccc1C(=O)OC(C)C', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68551CB0>, y=array([-4.76]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='COC(=O)C1=C(C)NC(=C(C1c2ccccc2N(=O)=O)C(=O)OC)C', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685D1B60>, y=array([0.74]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='OCC1OC(O)C(O)C(O)C1O', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685D3760>, y=array([-3.78]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CC2Nc1cc(Cl)c(cc1C(=O)N2c3ccccc3C)S(N)(=O)=O', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685668F0>, y=array([-2.16]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Oc2ccc1ncccc1c2', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685C6880>, y=array([-2.09]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CN(C)C(=O)Oc1cc(C)nn1c2ccccc2', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68567A70>, y=array([-2.03]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CC(=C)C=C', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685234C0>, y=array([0.52]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCC(=O)C', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68523060>, y=array([-1.92]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Nc1cccc2ccccc12', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC685D1540>, y=array([-1.37]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='Nc1cccc(Cl)c1', V_f=None, E_f=None, V_d=None),
#   MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x000001BC68565150>, y=array([-3.68]), weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='CCC(C)CC', V_f=None, E_f=None, V_d=None)]]

# %% [markdown]
# # Get MolecularDatasets

# %%
featurizer = featurizers.SimpleMoleculeMolGraphFeaturizer ()

train_dset = data.MoleculeDataset (train_data [0], featurizer)
scaler = train_dset.scaler

val_dset = data.MoleculeDataset(val_data [0], featurizer)
val_dset.normalize_targets(scaler)

test_dset = data.MoleculeDataset(test_data [0], featurizer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 featurizer = featurizers.SimpleMoleculeMolGraphFeaturizer ()
#       3 train_dset = data.MoleculeDataset (train_data [0], featurizer)
#       4 scaler = train_dset.scaler
#
# NameError: name 'featurizers' is not defined

# %% [markdown]
# # Get DataLoader

# %%
train_loader = data.build_dataloader(train_dset, num_workers=15)
val_loader = data.build_dataloader(val_dset, num_workers=15, shuffle=False)
test_loader = data.build_dataloader(test_dset, num_workers=15, shuffle=False)

# %% [markdown]
# # Message Passing Neural Networks

# %%
# output_transform = nn.UnscaleTransform.from_standard_scaler(scaler)
mp = nn.BondMessagePassing ()

# %% [markdown]
# # Aggregation

# %%
agg = nn.MeanAggregation ()

# %% [markdown]
# # Feed-Forward Networkd (FFN)

# %%
#output_transform = nn.UnscaleTransform.from_standard_scaler(scaler)
ffn = nn.RegressionFFN ()

# %% [markdown]
# # Batch Normalization

# %%
batch_norm = True

# %% [markdown]
# # Metrics

# %%
print(nn.metrics.MetricRegistry)
# Out:
# ClassRegistry {
#     'mse': <class 'chemprop.nn.metrics.MSE'>,
#     'mae': <class 'chemprop.nn.metrics.MAE'>,
#     'rmse': <class 'chemprop.nn.metrics.RMSE'>,
#     'bounded-mse': <class 'chemprop.nn.metrics.BoundedMSE'>,
#     'bounded-mae': <class 'chemprop.nn.metrics.BoundedMAE'>,
#     'bounded-rmse': <class 'chemprop.nn.metrics.BoundedRMSE'>,
#     'r2': <class 'chemprop.nn.metrics.R2Score'>,
#     'binary-mcc': <class 'chemprop.nn.metrics.BinaryMCCMetric'>,
#     'multiclass-mcc': <class 'chemprop.nn.metrics.MulticlassMCCMetric'>,
#     'roc': <class 'chemprop.nn.metrics.BinaryAUROC'>,
#     'prc': <class 'chemprop.nn.metrics.BinaryAUPRC'>,
#     'accuracy': <class 'chemprop.nn.metrics.BinaryAccuracy'>,
#     'f1': <class 'chemprop.nn.metrics.BinaryF1Score'>
# }

# %%
metrics = [nn.metrics.RMSE (), nn.metrics.MSE ()]

# %% [markdown]
# # Constructing the mpnn

# %%
mpnn = models.MPNN (mp,agg, ffn, batch_norm, metrics)
mpnn
# Out:
# MPNN(
#   (message_passing): BondMessagePassing(
#     (W_i): Linear(in_features=86, out_features=300, bias=False)
#     (W_h): Linear(in_features=300, out_features=300, bias=False)
#     (W_o): Linear(in_features=372, out_features=300, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (tau): ReLU()
#     (V_d_transform): Identity()
#     (graph_transform): Identity()
#   )
#   (agg): MeanAggregation()
#   (bn): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (predictor): RegressionFFN(
#     (ffn): MLP(
#       (0): Sequential(
#         (0): Linear(in_features=300, out_features=300, bias=True)
#       )
#       (1): Sequential(
#         (0): ReLU()
#         (1): Dropout(p=0.0, inplace=False)
#         (2): Linear(in_features=300, out_features=1, bias=True)
#       )
#     )
#     (criterion): MSE(task_weights=[[1.0]])
#     (output_transform): Identity()
#   )
#   (X_d_transform): Identity()
#   (metrics): ModuleList(
#     (0): RMSE(task_weights=[[1.0]])
#     (1-2): 2 x MSE(task_weights=[[1.0]])
#   )
# )

# %% [markdown]
# # Trainer

# %%
# Configure model checkpointing
checkpointing = ModelCheckpoint(
    "checkpoints",  # Directory where model checkpoints will be saved
    "best-{epoch}-{val_loss:.2f}",  # Filename format for checkpoints, including epoch and validation loss
    "val_loss",  # Metric used to select the best checkpoint (based on validation loss)
    mode="min",  # Save the checkpoint with the lowest validation loss (minimization objective)
    save_last=True,  # Always save the most recent checkpoint, even if it's not the best
)


trainer = pl.Trainer(
    logger=False,
    enable_checkpointing=True, # Use `True` if you want to save model checkpoints. The checkpoints will be saved in the `checkpoints` folder.
    enable_progress_bar=True,
    accelerator="auto",
    devices=1,
    max_epochs=20, # number of epochs to train for
    callbacks=[checkpointing], # Use the configured checkpoint callback
)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(mpnn, train_loader, val_loader)
# Out:
# C:\Users\leonz\anaconda3\envs\chemprop_env\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:881: Checkpoint directory C:\Users\leonz\PyCharmMiscProject\chemprop\checkpoints exists and is not empty.
# Loading `train_dataloader` to estimate number of stepping batches.
# C:\Users\leonz\anaconda3\envs\chemprop_env\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:429: Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
